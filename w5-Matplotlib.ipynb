# %% [markdown]
# ## <center>Visualization</center>
#
# **Why?**
#     * Verileri 'Exploratory Data Analysis' (EDA) süreci içerisinde anlamamıza ve herkesin anlamasına yardımcı olur.
#     * Veri setindeki şüphelerimize katkı sağlayabilir.
#     * A picture is worth a thousand words | Napoleon Bonaparte
#
# **Some Packages**
#     * Matplotlib
#     * Seaborn
#     * Plotly
#     * Bokeh
#     * NetworkX
#
# **References**
# Data to Viz: https://www.data-to-viz.com
# Data Viz Catalogue: https://datavizcatalogue.com
# Data Viz Project: https://datavizproject.com
# Python Graph Gallery: https://python-graph-gallery.com
#
# **From Data to Viz:** https://www.data-to-viz.com/img/poster/poster_big.png
#
# **Choosing a Good Chart:** https://extremepresentation.typepad.com/files/choosing-a-good-chart-09.pdf

# %% [markdown]
# ### Matplotlib
#
# Matplotlib, Python'da statik, animasyonlu ve etkileşimli görselleştirmeler oluşturmak için kapsamlı bir kütüphanedir.
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# **Site:** https://matplotlib.org/
#
# **User Guide:** https://matplotlib.org/contents.html

# %% [markdown]
# ### Kurulum

# %%
# !pip install matplotlib
# !conda install matplotlib

# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np

# %%
plt
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\METIN.USLU\\.conda\\envs\\lcw_env\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# dir(plt)

# %%
plt.figure( figsize=(10, 5) )

plt.plot()

plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Plot Title")

plt.legend(loc='center right')


plt.xticks([1, 2, 3, 4, 5])
plt.yticks([10, 20, 30, 40, 50])

# plt.xticks([1, 2, 3, 4, 5], ["1M", "2M", "3M", "4M", "5M"])
# plt.yticks([1, 2, 3, 4, 5], ["1K", "2K", "3K", "4K", "5K"])

plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
x = [1, 2, 3, 4]
y = [1, 4, 2, 3]

plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 2, 100)
x
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
# ...

# %%
plt.figure(figsize=(10, 5))
plt.plot(x, x, label='linear')
plt.plot(x, x**2, label='quadratic')
plt.plot(x, x**3, label='cubic')

plt.xlabel('X Values')
plt.ylabel('Y Values')

plt.title("Simple Plot")

plt.legend(loc='upper left')

plt.show()

# %%
names = ['A', 'B', 'C']
values = [10, 20, 40]

plt.figure(figsize=(12, 6))

plt.subplot(131)
plt.bar(names, values)

plt.subplot(132)
plt.scatter(names, values)

plt.subplot(133)
plt.plot(names, values)

plt.suptitle('Categorical Plotting')
plt.show()
